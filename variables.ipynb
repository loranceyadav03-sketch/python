# %%
age=20;
print("age:", age)
# Out:
# age: 20

# %%
# typecasting /type conversion
# two type
 1. implicit type casting and explicit type casting
# Out:
#   Cell In[11], line 3
#     1. implicit type casting and explicit type casting
#     ^
# IndentationError: unexpected indent

# %%
age=20
height=5.9
name="aditya"
print("name",type (name) ,name)
print("height", type (height), height)
print("age", type (age), age)
# Out:
# name <class 'str'> aditya
# height <class 'float'> 5.9
# age <class 'int'> 20

# %%
a=10
b=3
c=a+b
print(a,type(a))
print(b,type(b))
print(c,type(c))
# Out:
# 10 <class 'int'>
# 3 <class 'int'>
# 13 <class 'int'>

# %%
# type of  oprater
# arthmetic oprater
#

a=10
b=5
add_result =a+b
sub_result =a-b
multification_result =a*b
divition_result =a/b
floor_divition_result =a//b
modulus_result =a%b
exponent_result =a**b
print("add_result",add_result)
print("sub_result",sub_result)
print("multification_result",multification_result)
print("divition_result",divition_result)
print("floor_divition_result",floor_divition_result)
print("modulus_result",modulus_result)
print("exponent_result",exponent_result)
# Out:
# add_result 15
# sub_result 5
# multification_result 50
# divition_result 2.0
# floor_divition_result 2
# modulus_result 0
# exponent_result 100000

# %%
#comparision oprater
a=10
b=5
print("a==b",a==b)
print("a!=b",a!=b)
print("a>b",a>b)
print("a<b",a<b)
print("a>=b",a>=b)
print("a<=b",a<=b)

#bitwise oprater
a=10
b=5
print("a&b",a&b) # bitwise and
print("a|b",a|b) # bitwise or
print("a^b",a^b) # bitwise xor
print("~a",~a) # bitwise not
print("a<<1",a<<1) # bitwise left shift
print("a>>1",a>>1) # bitwise right shift


#
# Out:
# a==b False
# a!=b True
# a>b True
# a<b False
# a>=b True
# a<=b False
# a&b 0
# a|b 15
# a^b 15
# ~a -11
# a<<1 20
# a>>1 5

# %%
# assignment oprater
a=5
b=6

# %%
#logical oprater
a=10
b=20

# %%
#taking input from user
age=input("enter your age:")
print(age,type(age))
# Out:
# shgdgfhh <class 'str'>

# %%
a=10
b=10
print(a is b)
print(a==b)

print(id(a), id(b))
# Out:
# True
# True
# 140731881465240 140731881465240

# %%
#shallur copy and deep copy compresion
import copy 
print(a.copy.copy)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 #shallur copy and deep copy compresion
#       2 import copy
# ----> 3 print(a.copy.copy)
#
# AttributeError: 'int' object has no attribute 'copy'

# %%
#simple calculater
num1 = float(input("enter first number:"))
num2 =float(input("enter second number:"))

sum =num1 + num2
difference =num1 - num2
product = num1*num2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 #simple calculater
# ----> 2 num1 = float(input("enter first number:"))
#       3 num2 =float(input("enter second number:"))
#       4
#       5 sum =num1 + num2
#
# ValueError: could not convert string to float: '100 40 '
